# %% [markdown]
# # CONTINUOUS ASSESSMENT TEST 2 – PAPER 2 OF 2
# # BACHELOR OF COMMERCE – GROUP 3.1. F.
# # UNIT CODE: BCM 3103
# # BUSINESS INTELLIGENCE AND DATA ANALYTICS
# # DATE: 30TH JUNE 2025
# # INSTRUCTIONS:
# 1. You are NOT allowed to communicate with anyone (except the invigilator) during the test. This includes online communication.
# 2. You are required to complete the assessment individually.
# 3. You are required to complete the test in this Jupyter Notebook.
#
# # Name:
# # Student ID:

# %% [markdown]
# # Practical Tasks

# %% [markdown]
# ## 1. Import the necessary libraries

# %%
import pandas as pd

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load the data

# %%
# *** TASK 1. *** Provide the code to load the data from the URL specified below
# Store the data in a DataFrame called `paper2_data`
# url = 'https://github.com/course-files/RegressionAndClassification/raw/refs/heads/main/data/paper2_dataset.csv'

# %%
# *** TASK 2. *** Provide the code to display the first 5 rows of the dataset

# %% [markdown]
# ## 3. Identify the features and the target

# %%
# *** TASK 3. *** Provide the code to separate the features (independent variables) and the target variable (dependent variable).
# The features are the "Newsletter" and "PurchaseFrequency" columns. They should be stored in a DataFrame called `X`.
# The target variable is the "RepeatPurchase" column. It should be stored in a Series called `y`.

# %% [markdown]
# ## 4. Split the data into training and testing sets

# %%
# *** TASK 4. *** Provide the code to split the data into training and testing sets
# The training set should contain 70% of the data, and the testing set should contain 30% of the data.

# %% [markdown]
# ## 5. Design the decision tree classifier

# %%
# *** TASK 5. *** Provide the code to design the decision tree classifier using the CART algorithm and the Gini impurity criterion
# For the sake of reproducibility, set `random_state=53`

# %% [markdown]
# ## 6. Evaluate the model

# %%
# ** TASK 6. *** Provide the code to evaluate the model's performance using the `classification_report()` function

# %% [markdown]
# ## 7. Visualize the Decision Tree Classifier

# %%
# *** TASK 7. *** Provide the code to visualize the decision tree classifier using the `plot_tree()` function
